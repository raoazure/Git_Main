# %%
# Sample data as a list of lists or tuples
data = [
    (1, "Alice", 34),
    (2, "Bob", 45),
    (3, "Charlie", 29)
]

# Define column headers
columns = ["ID", "Name", "Age"]

# Create DataFrame
df = spark.createDataFrame(data, schema=columns)

# Display the result (display() is built into Databricks notebooks for rich tables)
display(df)
